// %% [markdown]
// # Chapter 1

// %% [markdown]
// hello world program

// %%
#include <stdio.h>
int main() {
    printf("hello");
    return 0;
}
// Out:
// hello

// %% [markdown]
// ```c
// #include <stdio.h>
//
// ```
//
// ^ this line tells the compiler to include the standard input and output library
//
// ```c
//
// int main() {
// ```
//
// ^ this declares the spefially reserved main function with no arguments snd specifies its return type as int
//
//
// ```c
//
// printf("hello");
// ```
//
// ^ this calls library function printf with string hello passed as argument
//
//
// ```c
//
// return 0;
// ```
//
// ^ it returns 0 because idk decide or look up reason but 0 is an integer
//
// ```c
// }
// ```
// this closes meets the opening bracecurly to encapsulate the insturctions of main
